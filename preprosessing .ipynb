# %%
import nltk
nltk.download('vader_lexicon')

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid=SentimentIntensityAnalyzer()

# %%
a='This is good movie'
sid.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
from google.colab import files
uploaded=files.upload()
for fn in uploaded.keys('nyka_top_brands_cosmetics_product_review.csv')
print("user uploaded files"{name}" with length{length} bytes",format(name=fn, length=len(uploaded[fn])))
# Out:
#   Input In [13]
#     for fn in uploaded.keys('nyka_top_brands_cosmetics_product_review.csv')
#                                                                            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiments = SentimentIntensityAnalyzer()
import re
import os

# %%
df = pd.read_csv("Amazon.txt", delimiter='\t')

# %%
print(df.head())
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
df=pd.read_csv("nyka_top_brands_cosmetics_product_reviews.csv",delimiter='\t')

# %%
print(df.head())
# Out:
#   product_id,brand_name,review_id,review_title,review_text,author,review_rating,is_a_buyer,product_title,mrp,price,product_rating,product_rating_count,product_tags
# 0  781070,Olay,16752142,Worth buying 50g one,Work...
# 1  781070,Olay,14682550,Best cream to start ur da...
# 2  781070,Olay,15618995,perfect for summers dry f...
# 3  781070,Olay,13474509,Not a moisturizer,"i have...
# 4  781070,Olay,16338982,Average,It's not that goo...

# %%
df.head()
# Out:
#   product_id,brand_name,review_id,review_title,review_text,author,review_rating,is_a_buyer,product_title,mrp,price,product_rating,product_rating_count,product_tags
# 0  781070,Olay,16752142,Worth buying 50g one,Work...
# 1  781070,Olay,14682550,Best cream to start ur da...
# 2  781070,Olay,15618995,perfect for summers dry f...
# 3  781070,Olay,13474509,Not a moisturizer,"i have...
# 4  781070,Olay,16338982,Average,It's not that goo...

# %%
df
# Out:
#       product_id,brand_name,review_id,review_title,review_text,author,review_rating,is_a_buyer,product_title,mrp,price,product_rating,product_rating_count,product_tags
# 0      781070,Olay,16752142,Worth buying 50g one,Work...
# 1      781070,Olay,14682550,Best cream to start ur da...
# 2      781070,Olay,15618995,perfect for summers dry f...
# 3      781070,Olay,13474509,Not a moisturizer,"i have...
# 4      781070,Olay,16338982,Average,It's not that goo...
# ...                                                  ...
# 61279  1044490,Herbal Essences,17769058,Good,I use th...
# 61280  1044490,Herbal Essences,17766838,Great,This sh...
# 61281  1044490,Herbal Essences,17765866,Really mild a...
# 61282  1044490,Herbal Essences,17761057,Amazing produ...
# 61283  4633369,Colorbar,25987603,Not good,It is so ir...
#
# [61284 rows x 1 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
df
# Out:
#       product_id,brand_name,review_id,review_title,review_text,author,review_rating,is_a_buyer,product_title,mrp,price,product_rating,product_rating_count,product_tags
# 0      781070,Olay,16752142,Worth buying 50g one,Work...
# 1      781070,Olay,14682550,Best cream to start ur da...
# 2      781070,Olay,15618995,perfect for summers dry f...
# 3      781070,Olay,13474509,Not a moisturizer,"i have...
# 4      781070,Olay,16338982,Average,It's not that goo...
# ...                                                  ...
# 61279  1044490,Herbal Essences,17769058,Good,I use th...
# 61280  1044490,Herbal Essences,17766838,Great,This sh...
# 61281  1044490,Herbal Essences,17765866,Really mild a...
# 61282  1044490,Herbal Essences,17761057,Amazing produ...
# 61283  4633369,Colorbar,25987603,Not good,It is so ir...
#
# [61284 rows x 1 columns]

# %%
print(os.listdir())
# Out:
# ['.android', '.astropy', '.bash_history', '.cache', '.conda', '.condarc', '.config', '.continuum', '.dotnet', '.eclipse', '.emulator_console_auth_token', '.gitconfig', '.gradle', '.ipynb_checkpoints', '.ipython', '.jupyter', '.m2', '.matplotlib', '.p2', '.templateengine', '.VirtualBox', '.vscode', '10exp.jks', '3D Objects', 'abs.jks', 'Amazon.txt', 'anaconda3', 'AndroidStudioProjects', 'AppData', 'Application Data', 'c++', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'eclipse', 'eclipse-workspace', 'Expriment2_Lab.ipynb', 'Favorites', 'FrameCreate.java', 'git', 'hello.cpp', 'hello.exe', 'Links', 'Local Settings', 'manasi.cpp', 'manasi.exe', 'movies.csv', 'Music', 'My Documents', 'Myanshi mental.cpp', 'Myanshi mental.txt', 'mysql-init1.txt', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{87fc2748-67dd-11ed-a547-86b698295f66}.TM.blf', 'NTUSER.DAT{87fc2748-67dd-11ed-a547-86b698295f66}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{87
# ...

# %%
df=pd.read_csv("nyka_top_brands_cosmetics_product_reviews.csv")

# %%
df
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
df.isnull().sum()
# Out:
# product_id                  0
# brand_name                  0
# review_id                   0
# review_title                0
# review_text                 8
# author                      0
# review_rating               1
# is_a_buyer                  0
# product_title               0
# mrp                         0
# price                       0
# product_rating              0
# product_rating_count        0
# product_tags            47782
# dtype: int64

# %%
missing_values=["N/a","na",np.nan]
df=pd.read_csv("nyka_top_brands_cosmetics_product_reviews.csv",na_values=missing_values)

# %%
df.isnull().sum()
# Out:
# product_id                  0
# brand_name                  0
# review_id                   0
# review_title                0
# review_text                 8
# author                      0
# review_rating               1
# is_a_buyer                  0
# product_title               0
# mrp                         0
# price                       0
# product_rating              0
# product_rating_count        0
# product_tags            47782
# dtype: int64

# %%
df.drop(['product_tags'],axis=1)
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
df.isnull().sum()
# Out:
# product_id                  0
# brand_name                  0
# review_id                   0
# review_title                0
# review_text                 8
# author                      0
# review_rating               1
# is_a_buyer                  0
# product_title               0
# mrp                         0
# price                       0
# product_rating              0
# product_rating_count        0
# product_tags            47782
# dtype: int64

# %%
df['product_tags']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 61279    FEATURED
# 61280    FEATURED
# 61281    FEATURED
# 61282    FEATURED
# 61283         NaN
# Name: product_tags, Length: 61284, dtype: object

# %%
df
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
for col in df.columns:    #remove column product _tags
    if 'product_tags' in col:
        del df[col]
        df

# %%
df
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
df.isnull().sum()
# Out:
# product_id              0
# brand_name              0
# review_id               0
# review_title            0
# review_text             8
# author                  0
# review_rating           1
# is_a_buyer              0
# product_title           0
# mrp                     0
# price                   0
# product_rating          0
# product_rating_count    0
# dtype: int64

# %%
df.dropna() #remove null value
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
df
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
df.isnull().sum()
# Out:
# product_id              0
# brand_name              0
# review_id               0
# review_title            0
# review_text             8
# author                  0
# review_rating           1
# is_a_buyer              0
# product_title           0
# mrp                     0
# price                   0
# product_rating          0
# product_rating_count    0
# dtype: int64

# %%
df1=df.dropna(how='any') #if any value is null then row is removed

# %% [markdown]
# df1

# %%
df1
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
df1.isnull().sum() # removed all null values
# Out:
# product_id              0
# brand_name              0
# review_id               0
# review_title            0
# review_text             0
# author                  0
# review_rating           0
# is_a_buyer              0
# product_title           0
# mrp                     0
# price                   0
# product_rating          0
# product_rating_count    0
# dtype: int64

# %%
df1['product_id'].describe()
# Out:
# count    6.127500e+04
# mean     7.982746e+05
# std      1.281263e+06
# min      2.500000e+02
# 25%      1.604880e+05
# 50%      4.524430e+05
# 75%      7.665290e+05
# max      7.749427e+06
# Name: product_id, dtype: float64

# %%
review_example=df1.review_text[2301] #displaying randow rewiew from dataset
review_example
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 review_example=df1.review_text[2301] #displaying randow rewiew from dataset
#       2 review_example
#
# NameError: name 'df1' is not defined

# %%
review_example=re.sub("[^a-zA-Z]",' ',review_example)    #removed all punctuation and number from review
review_example
# Out:
# 'Ok but not that great miracle  Must wait at least   months to see any changes '

# %%
review_example=review_example.lower().split() #converted into lower case 
review_example
# Out:
# ['ok',
#  'but',
#  'not',
#  'that',
#  'great',
#  'miracle',
#  'must',
#  'wait',
#  'at',
#  'least',
#  'months',
#  'to',
#  'see',
#  'any',
#  'changes']

# %%
rt= lambda x:re.sub("[^a-zA-Z]",' ',str(x))
df1["review_text"]=df1["review_text"].map(rt)
df1["review_text"]=df1["review_text"].str.lower()
df1.head()
#removed punctuate and number applyied on all dataset
# Out:
# C:\Users\MANASI D GURAV\AppData\Local\Temp\ipykernel_1940\1317534307.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["review_text"]=df1["review_text"].map(rt)
# C:\Users\MANASI D GURAV\AppData\Local\Temp\ipykernel_1940\1317534307.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["review_text"]=df1["review_text"].str.lower()
#    product_id brand_name  review_id                         review_title  \
# 0      781070       Olay   16752142                 Worth buying 50g one
# ...

# %%
df1
# Out:
#        product_id       brand_name  review_id  \
# 0          781070             Olay   16752142
# 1          781070             Olay   14682550
# 2          781070             Olay   15618995
# 3          781070             Olay   13474509
# 4          781070             Olay   16338982
# ...           ...              ...        ...
# 61279     1044490  Herbal Essences   17769058
# 61280     1044490  Herbal Essences   17766838
# 61281     1044490  Herbal Essences   17765866
# 61282     1044490  Herbal Essences   17761057
# 61283     4633369         Colorbar   25987603
#
#                               review_title  \
# 0                     Worth buying 50g one
# 1               Best cream to start ur day
# 2      perfect for summers dry for winters
# 3                        Not a moisturizer
# 4                                  Average
# ...                                    ...
# 61279                                 Good
# 61280                                Great
# ...

# %%
# !pip3 install vaderSentiment

# !pip3 install TextBlob

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
df1[["polarity","subjectivity"]]=df1['review_text'].apply(lambda Text:pd.Series(TextBlob(Text).sentiment))

for index, row in df1['review_text'].iteritems():
    score=SentimentIntensityAnalyzer().polarity_scores(row)
    
    neg=score['neg']
    neu=scroe['neu']
    pos=score['pos']
    
    if neg>pos:
        df1.loc[index,'sentiment']="Negative"
    elif pos>neg:
        df1.loc[index,'sentiment']="Positive"
    else:
        df1.loc[index,'sentiment']="Neutral"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 2>()
#       1 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# ----> 2 df1[["polarity","subjectivity"]]=df1['review_text'].apply(lambda Text:pd.Series(TextBlob(Text).sentiment))
#       4 for index, row in df1['review_text'].iteritems():
#       5     score=SentimentIntensityAnalyzer().polarity_scores(row)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# ...
